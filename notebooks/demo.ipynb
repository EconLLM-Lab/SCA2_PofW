# %% [markdown]
# # SCA 2.0 Demo
#
# This notebook is intentionally slim and imports the refactored package.
#
# It demonstrates configuration inspection and a no-network cost estimate.

# %%
from sca2_datagen.config import CONFIG, GPS_DIMENSIONS, CostTracker

print(CONFIG.teacher_model)
print(list(GPS_DIMENSIONS))

# %%
tracker = CostTracker()
estimate = tracker.estimate_run(
    CONFIG.with_overrides(scenarios_per_dim=5),
    countries=["MEX", "USA"],
    sample_sizes=[100, 350, 500],
)

estimate
